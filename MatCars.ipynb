# %% [markdown]
# <a href="https://colab.research.google.com/github/beymaral/BEYMARAL_car/blob/main/MatCars.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("mtcars.csv")

# %%
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
arr = df.columns.tolist()
arr_1 = [i.upper() for i in arr]
arr_1
# Out:
# ['MODEL',
#  'MPG',
#  'CYL',
#  'DISP',
#  'HP',
#  'DRAT',
#  'WT',
#  'QSEC',
#  'VS',
#  'AM',
#  'GEAR',
#  'CARB']

# %%
dict_ = {k: v for k, v in zip(arr, arr_1)}

# %%
df.rename(dict_, axis = 1, inplace=True)

dict_
# Out:
# {'model': 'MODEL',
#  'mpg': 'MPG',
#  'cyl': 'CYL',
#  'disp': 'DISP',
#  'hp': 'HP',
#  'drat': 'DRAT',
#  'wt': 'WT',
#  'qsec': 'QSEC',
#  'vs': 'VS',
#  'am': 'AM',
#  'gear': 'GEAR',
#  'carb': 'CARB'}

# %%
df.reindex(columns=arr_1)
# Out:
#                   MODEL   MPG  CYL   DISP   HP  DRAT     WT   QSEC  VS  AM  \
# 0             Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1         Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2            Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3        Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4     Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
# 5               Valiant  18.1    6  225.0  105  2.76  3.460  20.22   1   0
# 6            Duster 360  14.3    8  360.0  245  3.21  3.570  15.84   0   0
# 7             Merc 240D  24.4    4  146.7   62  3.69  3.190  20.00   1   0
# 8              Merc 230  22.8    4  140.8   95  3.92  3.150  22.90   1   0
# 9              Merc 280  19.2    6  167.6  123  3.92  3.440  18.30   1   0
# 10            Merc 280C  17.8    6  167.6  123  3.92  3.440  18.90   1   0
# ...

# %%
df.MODEL.unique()
# Out:
# array(['Mazda RX4', 'Mazda RX4 Wag', 'Datsun 710', 'Hornet 4 Drive',
#        'Hornet Sportabout', 'Valiant', 'Duster 360', 'Merc 240D',
#        'Merc 230', 'Merc 280', 'Merc 280C', 'Merc 450SE', 'Merc 450SL',
#        'Merc 450SLC', 'Cadillac Fleetwood', 'Lincoln Continental',
#        'Chrysler Imperial', 'Fiat 128', 'Honda Civic', 'Toyota Corolla',
#        'Toyota Corona', 'Dodge Challenger', 'AMC Javelin', 'Camaro Z28',
#        'Pontiac Firebird', 'Fiat X1-9', 'Porsche 914-2', 'Lotus Europa',
#        'Ford Pantera L', 'Ferrari Dino', 'Maserati Bora', 'Volvo 142E'],
#       dtype=object)

# %%
df["BRAND"] = df.MODEL.map(lambda i: i.split()[0])

# %%
clo = ['BRAND', 'MODEL',
 'MPG',
 'CYL',
 'DISP',
 'HP',
 'DRAT',
 'WT',
 'QSEC',
 'VS',
 'AM',
 'GEAR',
 'CARB']

# %%
df.columns.tolist()
# Out:
# ['MODEL',
#  'MPG',
#  'CYL',
#  'DISP',
#  'HP',
#  'DRAT',
#  'WT',
#  'QSEC',
#  'VS',
#  'AM',
#  'GEAR',
#  'CARB',
#  'BRAND']

# %%
df = df.reindex(columns = clo)

# %%
df['MODEL'] = df.MODEL.map(lambda i: ' '.join(i.split()[1:]))

# %%
df.head()
# Out:
#     BRAND       MODEL   MPG  CYL   DISP   HP  DRAT     WT   QSEC  VS  AM  \
# 0   Mazda         RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1
# 1   Mazda     RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1
# 2  Datsun         710  22.8    4  108.0   93  3.85  2.320  18.61   1   1
# 3  Hornet     4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0
# 4  Hornet  Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0
#
#    GEAR  CARB
# 0     4     4
# 1     4     4
# 2     4     1
# 3     3     1
# 4     3     2

# %%
dict_am ={0: 'manual', 1: 'auto'}

# %%
#OR df.AM = df.AM.replace(dict_am)
df.AM = df.AM.map(dict_am)

# %%
df.head()
# Out:
#     BRAND       MODEL   MPG  CYL   DISP   HP  DRAT     WT   QSEC  VS      AM  \
# 0   Mazda         RX4  21.0    6  160.0  110  3.90  2.620  16.46   0    auto
# 1   Mazda     RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0    auto
# 2  Datsun         710  22.8    4  108.0   93  3.85  2.320  18.61   1    auto
# 3  Hornet     4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1  manual
# 4  Hornet  Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0  manual
#
#    GEAR  CARB
# 0     4     4
# 1     4     4
# 2     4     1
# 3     3     1
# 4     3     2

# %%
cyl_types = df.CYL.unique().tolist()

# %%
cyl_types
# Out:
# [6, 4, 8]

# %%
type(df.value_counts('BRAND'))
# Out:
# pandas.core.series.Series

# %%
hp_4 = df[df.CYL==4].HP.median()

# %%
hp_6 = df[df.CYL==6].HP.median()

# %%
hp_8 = df[df.CYL==8].HP.median()

# %%
hp_4, hp_6, hp_8
# Out:
# (91.0, 110.0, 192.5)

# %%
import seaborn as sns
sns.lmplot(x='DISP', y='HP', data = df)

# %%
#df.sort_values('QSEC', ascending=False,inplace=True)(df_mobi.balance(10))

df.sort_values('QSEC').iloc[:5, 0].values.tolist()
# Out:
# ['Ford', 'Maserati', 'Camaro', 'Ferrari', 'Duster']

# %%
df.describe()
# Out:
#              MPG        CYL        DISP          HP       DRAT         WT  \
# count  32.000000  32.000000   32.000000   32.000000  32.000000  32.000000
# mean   20.090625   6.187500  230.721875  146.687500   3.596563   3.217250
# std     6.026948   1.785922  123.938694   68.562868   0.534679   0.978457
# min    10.400000   4.000000   71.100000   52.000000   2.760000   1.513000
# 25%    15.425000   4.000000  120.825000   96.500000   3.080000   2.581250
# 50%    19.200000   6.000000  196.300000  123.000000   3.695000   3.325000
# 75%    22.800000   8.000000  326.000000  180.000000   3.920000   3.610000
# max    33.900000   8.000000  472.000000  335.000000   4.930000   5.424000
#
#             QSEC         VS       GEAR     CARB
# count  32.000000  32.000000  32.000000  32.0000
# mean   17.848750   0.437500   3.687500   2.8125
# std     1.786943   0.504016   0.737804   1.6152
# min    14.500000   0.000000   3.000000   1.0000
# 25%    16.892500   0.000000   3.000000   2.0000
# ...

# %%
df[df.AM=='auto'].MPG.mean()
# Out:
# 24.39230769230769

# %%
df[df.AM=='manual'].MPG.mean()
# Out:
# 17.147368421052633

# %%
df[df.AM=='auto'].value_counts('GEAR')
# Out:
# GEAR
# 4    8
# 5    5
# dtype: int64

# %%
df[df.AM=='manual'].value_counts('GEAR')
# Out:
# GEAR
# 3    15
# 4     4
# dtype: int64
